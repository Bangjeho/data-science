# %%
import tensorflow as tf

# %%
hello = tf.constant('hello, tensorflow')

sess = tf.Session()

sess.run(hello)
# Out:
# b'hello, tensorflow'

# %%
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)

list_1 = [1,3]
list_2 = [4,5]

adder_node = a + b

sess = tf.Session()

sess.run(adder_node, feed_dict = {a: list_1, b: list_2})
# Out:
# array([5., 8.], dtype=float32)

# %%
#build to Linear regrection model
# train_X = [1,2,3]
# train_y = [1,2,3]

X = tf.placeholder(tf.float32, shape =[None])
Y = tf.placeholder(tf.float32, shape =[None])
w = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

hypothesis = X * w + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()

sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, w_val, b_val, _ = sess.run([cost,w,b,train],
                                         feed_dict = {X : [1,2,3,4,5],
                                                      Y : [2,4,5,7,8]})
    if step % 20 == 0:
        print(step,cost_val,w_val,b_val)
# Out:
# 0 59.066467 [-0.3091684] [0.8485602]
# 20 0.11946678 [1.3364022] [1.2618093]
# 40 0.11088278 [1.3540137] [1.2269269]
# 60 0.1044364 [1.3636055] [1.1924272]
# 80 0.098806664 [1.3725382] [1.1601777]
# 100 0.09389011 [1.3808857] [1.1300403]
# 120 0.089596495 [1.3886867] [1.1018766]
# 140 0.08584683 [1.3959765] [1.0755574]
# 160 0.08257226 [1.4027892] [1.0509617]
# 180 0.079712465 [1.4091557] [1.0279768]
# 200 0.07721503 [1.4151052] [1.0064971]
# 220 0.07503401 [1.420665] [0.9864244]
# 240 0.07312932 [1.4258608] [0.9676662]
# 260 0.07146594 [1.4307162] [0.95013654]
# 280 0.0700133 [1.4352536] [0.933755]
# 300 0.06874466 [1.4394939] [0.9184463]
# 320 0.067636885 [1.4434564] [0.90414006]
# 340 0.06666924 [1.4471595] [0.89077073]
# 360 0.06582433 [1.4506202] [0.87827694]
# 380 0.06508641 [1.4538541] [0.86660147]
# 400 0.06444204 [1.4568762] [0.8556907]
# 420 0.063879184 [1.4597005] [0.84549445]
# 440 0.06338776 [1.4623396] [0.8359659]
# 460 0.06295858 [1.464806] [0.8270615]
# 480 0.06258376 [1.4671109] [0.8187403]
# 500 0.062256377 [1.4692649] [0.81096387]
# 520 0.061970543 [1.4712777] [0.80369663]
# 540 0.061720878 [1.4731588] [0.79690546]
# 560 0.061502874 [1.4749166] [0.79055905]
# 580 0.061312497 [1.4765593] [0.78462833]
# 600 0.06114617 [1.4780945] [0.779086]
# 620 0.06100095 [1.4795291] [0.7739065]
# 640 0.060874183 [1.4808698] [0.7690662]
# 660 0.060763437 [1.4821225] [0.7645431]
# 680 0.060666703 [1.4832933] [0.7603162]
# 700 0.0605822 [1.4843874] [0.7563661]
# 720 0.060508467 [1.48541] [0.7526747]
# 740 0.060444027 [1.4863654] [0.7492249]
# 760 0.06038777 [1.4872584] [0.7460011]
# 780 0.060338657 [1.4880928] [0.7429885]
# 800 0.06029572 [1.4888726] [0.7401734]
# 820 0.06025824 [1.4896013] [0.7375425]
# 840 0.060225565 [1.4902824] [0.73508376]
# 860 0.060197033 [1.4909188] [0.73278606]
# 880 0.060172044 [1.4915136] [0.7306387]
# 900 0.06015023 [1.4920695] [0.728632]
# 920 0.060131203 [1.4925888] [0.7267569]
# 940 0.06011454 [1.493074] [0.7250046]
# 960 0.060100097 [1.4935277] [0.7233671]
# 980 0.060087334 [1.4939516] [0.72183675]
# 1000 0.060076315 [1.4943477] [0.7204068]
# 1020 0.060066663 [1.4947177] [0.7190703]
# 1040 0.060058217 [1.4950638] [0.71782136]
# 1060 0.060050845 [1.4953871] [0.7166542]
# 1080 0.060044356 [1.4956893] [0.71556336]
# 1100 0.060038757 [1.4959716] [0.71454406]
# 1120 0.06003387 [1.4962354] [0.7135916]
# 1140 0.060029525 [1.4964819] [0.7127015]
# 1160 0.0600258 [1.4967123] [0.7118697]
# 1180 0.06002248 [1.4969276] [0.7110923]
# 1200 0.060019683 [1.4971288] [0.7103659]
# 1220 0.06001717 [1.4973168] [0.7096871]
# 1240 0.060015 [1.4974926] [0.7090527]
# 1260 0.060013127 [1.4976568] [0.7084598]
# 1280 0.06001147 [1.4978102] [0.70790577]
# 1300 0.060009994 [1.4979535] [0.7073881]
# 1320 0.060008727 [1.4980875] [0.7069043]
# 1340 0.06000771 [1.4982128] [0.7064522]
# 1360 0.060006678 [1.4983299] [0.70602965]
# 1380 0.060005803 [1.4984393] [0.7056348]
# 1400 0.06000508 [1.4985415] [0.7052657]
# 1420 0.060004413 [1.4986371] [0.7049206]
# 1440 0.060003866 [1.4987262] [0.7045985]
# 1460 0.06000339 [1.4988096] [0.70429736]
# 1480 0.060003005 [1.4988877] [0.704016]
# 1500 0.060002584 [1.4989605] [0.70375305]
# 1520 0.06000222 [1.4990284] [0.7035074]
# 1540 0.06000195 [1.4990921] [0.70327777]
# 1560 0.06000172 [1.4991515] [0.7030631]
# 1580 0.060001504 [1.4992071] [0.7028626]
# 1600 0.06000129 [1.4992589] [0.7026752]
# 1620 0.060001124 [1.4993075] [0.7025]
# 1640 0.060001016 [1.4993528] [0.7023364]
# 1660 0.060000826 [1.4993951] [0.7021835]
# 1680 0.060000785 [1.4994347] [0.70204055]
# 1700 0.060000677 [1.4994717] [0.701907]
# 1720 0.06000061 [1.4995062] [0.7017821]
# 1740 0.06000051 [1.4995385] [0.70166546]
# 1760 0.06000046 [1.4995688] [0.7015565]
# 1780 0.06000037 [1.4995971] [0.70145464]
# 1800 0.06000038 [1.4996234] [0.7013595]
# 1820 0.06000033 [1.4996479] [0.7012706]
# 1840 0.06000027 [1.4996711] [0.7011874]
# 1860 0.060000308 [1.4996927] [0.7011097]
# 1880 0.060000174 [1.4997126] [0.70103705]
# 1900 0.060000163 [1.4997315] [0.7009693]
# 1920 0.06000015 [1.499749] [0.70090586]
# 1940 0.06000013 [1.4997655] [0.7008466]
# 1960 0.060000133 [1.4997808] [0.7007912]
# 1980 0.06000017 [1.4997952] [0.7007395]
# 2000 0.06000007 [1.4998087] [0.700691]

# %%
#test _lr model
print(sess.run(hypothesis, feed_dict = {X : [10]}))
print(sess.run(hypothesis,feed_dict = {X : [5]}))
# Out:
# [15.698778]
# [8.199735]
